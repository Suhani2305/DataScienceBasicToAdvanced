# %%
import pandas as pd  
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['fare'].mean()  # mean
# Out:
# np.float64(32.204207968574636)

# %%
from scipy import stats
data = np.array([10,20,30,40,50])
stats.gmean(data)  # geometric mean
# Out:
# np.float64(26.051710846973528)

# %%
stats.hmean(data)  # harmonic mean
# Out:
# np.float64(21.8978102189781)

# %%
stats.trim_mean(data, 0.05)  # trimmed mean
# Out:
# np.float64(30.0)

# %%
data.mean()  # mean
# Out:
# np.float64(30.0)

# %% [markdown]
# ## Median

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['age'].mean()  # mean
# df['age'].median()  # median
# Out:
# np.float64(29.69911764705882)

# %% [markdown]
# ## Mode

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df['class'].mode()  # mode
# Out:
# 0    Third
# Name: class, dtype: category
# Categories (3, object): ['First', 'Second', 'Third']

# %%
df['class'].value_counts()  # frequency of each category
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
df['sibsp'].value_counts()  # frequency of each category
# Out:
# sibsp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
sns.histplot(df,x = 'age', kde = True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Lets find range of a data
df = np.array([10, 20, 30, 40, 50])
np.ptp(df)
# Out:
# np.int64(40)

# %% [markdown]
# ### 🔹 What `np.ptp()` does:
#
# - `np.ptp()` stands for **"peak to peak"**.
# - It calculates the **range** of values in an array, i.e.:
#
# \[
# \text{ptp} = \max(\text{array}) - \min(\text{array})
# \]
#
# ---
#
# ### Example:
#
# ```python
# import numpy as np
#
# df = np.array([10, 20, 30, 40, 50])
# print(np.ptp(df))   # Output: 40

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Generating a dataset with potential outliers
np.random.seed(0)
data = np.random.normal(100, 20, 200)
data = np.append(data, [300, 5])  # Adding potential outliers

# Calculating IQR
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1

# Defining the outlier criteria (1.5 times the IQR)
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identifying outliers
outliers = (data < lower_bound) | (data > upper_bound)

# Removing outliers
data_no_outliers = data[~outliers]

# Plotting the original data with outliers
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.boxplot(data=data)
plt.title('Original Data with Outliers')

# Plotting the data after removing outliers
plt.subplot(1, 2, 2)
sns.boxplot(data=data_no_outliers)
plt.title('Data After Removing Outliers')

plt.show()

# %%
# import library

import numpy as np

# create a dataset

df = np.array([2,3,4,5,6])
mean = np.mean(df)
var = np.var(df, ddof=1)
var

# ddof=0 → jab pura population data ho.
# ddof=1 → jab sample data ho.
# Out:
# np.float64(2.5)

# %%
# import library
import numpy as np

df = np.array([2,3,4,5,6])

#calculate standard deviation
std = np.std(df, ddof=1)
std
print("Standard Deviation: ", std)
# calculate the standard error
se = std/np.sqrt(len(df))
print("Standard Error: ", se)
# Out:
# Standard Deviation:  1.5811388300841898
# Standard Error:  0.7071067811865476
